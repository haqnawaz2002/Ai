# %% [markdown]
# # Decision Tree Classifier
#
# A Supervised Machine Learning Algorithm, used to build classification and regression models in the form of a tree structure.
#
# A decision tree is a tree where each -
#
# * Node - a feature(attribute)
# * Branch - a decision(rule)
# * Leaf - an outcome(categorical or continuous)
#
# There are many algorithms to build decision trees, here we are going to discuss ID3 algorithm

# %% [markdown]
# ###  Intuitive Introduction

# %% [markdown]
# <div>
#     <img src = "attachment:image.png" width = 600 />
# </div>

# %% [markdown]
# <div>
#     <img src = "attachment:image.png" width = 600 />
# </div>

# %% [markdown]
# What the shopkeeper just did was to help you walk through a decision tree to narrow down your choices. Pictorially it would look like —

# %% [markdown]
# <div>
#     <img src = "attachment:image.png"  />
# </div>

# %% [markdown]
# The “Yes” and “No” arrows are branches and the questions are our nodes with leaves as a buy or Don’t buy decision and hence we call it a decision tree.
#
#
# Decision trees are everywhere. Knowingly or unknowingly we use them every day. When you say, “If it’s raining, I will bring an umbrella,” you’ve just constructed a simple decision tree like this —

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# It is a very simplistic decision tree and doesn’t account for too many situations. For instance, what if it is windy and raining outside? You would rather take a rain jacket instead of an umbrella and your decision tree would look like —

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# __What if it is snowing? or the wind is too strong?__ You can keep adding conditions to this tree and it can keep getting bigger (deeper) with more branches to handle more situations. Simple enough, right? Well, that is the power of decision trees!
#
# Decision trees are very simple and understandable. They allow you to see exactly how a particular decision is reached.

# %% [markdown]
# Decision trees can be used for both classification and regression tasks

# %% [markdown]
# ### Decision Tree Classification

# %% [markdown]
# Let’s consider a classification task where you have to classify an Iris flower data set into 3 different categories based on values of some attributes — Iris Setosa, Iris Versicolor and Iris Virginica; Setosa, Versicolor and Virginica are different varieties of Iris flowers. There are some attribute values which differ among these. We will use their petal length and petal width as attributes or features of interest.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# We can separate these varieties of iris flowers with two different lines into 3 boxy regions. We can separate Setosa from the other two with a horizontal line which corresponds to length = 2.45 cm. An Iris flower with petal length less than 2.45 cm is a Setosa variety. Above this line would either be a Versicolor or a Virginica.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Let‘s draw another line to separate the other two varieties. Versicolor and Virginica can be separated by a vertical line corresponding to petal width = 1.75 cm. Note that this condition is on top of the earlier condition on petal length.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Now we have our lines which divide the data into 3 different parts. The decision tree for this looks like —
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Now when you see a new Iris flower just measure its petal length and width and run it down the decision tree and you can classify which variety of Iris is this. For example, an Iris flower you found while on a hike had petal length 2.48 cm and petal width 1.86 cm, your decision tree tells you that this is Iris Virginica since petal length >2.45 cm and petal width > 1.75 cm.

# %% [markdown]
# ### How to build Decision Tree

# %% [markdown]
# There are couple of algorithms there to build a decision tree —
# * __CART (Classification and Regression Trees)__ → uses Gini Index(Classification) as metric.
# * __ID3 (Iterative Dichotomiser 3)__ → uses Entropy function and Information gain as metrics.

# %% [markdown]
# ### ID3 algorithm
#
# It is a classification algorithm that follows a greedy approach by selecting a best attribute that yields __maximum Information Gain(IG) or minimum Entropy(H).__
#
#
# The steps in ID3 algorithm are as follows:
#
# 1. Calculate entropy for dataset.
#
#
# 2. For each attribute/feature.
#
#     2.1. Calculate entropy for all its categorical values.
#
#     2.2. Calculate information gain for the feature.
#
#
# 3. Find the feature with maximum information gain.
#
#
# 4. Repeat it until we get the desired tree.

# %% [markdown]
# ### What is Entropy and Information gain?
#
# __Entropy__ is a measure of the amount of uncertainty in the dataset S. Mathematical Representation of Entropy is shown here -
#
# ![image.png](attachment:image.png)
#
#
# In ID3, entropy is calculated for each remaining attribute. The attribute with the smallest entropy is used to split the set S on that particular iteration.
#
# __Entropy = 0 implies it is of pure class, that means all are of same category.__

# %% [markdown]
# __Information Gain IG(A)__ tells us how much uncertainty in S was reduced after splitting set S on attribute A. Mathematical representation of Information gain is shown here -
#
# ![image.png](attachment:image.png)
#
#
#
# The attribute with the largest information gain is used to split the set S on that particular iteration.

# %% [markdown]
# ### Use ID3 algorithm on a data

# %% [markdown]
# We'll discuss it here mathematically.
# So, Let's take an example to make it more clear.
#
# <!-- ![image.png](attachment:image.png) -->

# %% [markdown]
# <table>
#   <thead>
#     <tr>
#       <th>Day</th>
#       <th>Outlook</th>
#       <th>Temperature</th>
#       <th>Humidity</th>
#       <th>Windy</th>
#       <th>PlayTennis</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>Sunny</td>
#       <td>Hot</td>
#       <td>High</td>
#       <td>Weak</td>
#       <td>No</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>Sunny</td>
#       <td>Hot</td>
#       <td>High</td>
#       <td>Strong</td>
#       <td>No</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>Overcast</td>
#       <td>Hot</td>
#       <td>High</td>
#       <td>Weak</td>
#       <td>Yes</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>Rain</td>
#       <td>Mild</td>
#       <td>High</td>
#       <td>Weak</td>
#       <td>Yes</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>Rain</td>
#       <td>Cool</td>
#       <td>Normal</td>
#       <td>Weak</td>
#       <td>Yes</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>Rain</td>
#       <td>Cool</td>
#       <td>Normal</td>
#       <td>Strong</td>
#       <td>No</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>Overcast</td>
#       <td>Cool</td>
#       <td>Normal</td>
#       <td>Strong</td>
#       <td>Yes</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>Sunny</td>
#       <td>Mild</td>
#       <td>High</td>
#       <td>Weak</td>
#       <td>No</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>Sunny</td>
#       <td>Cool</td>
#       <td>Normal</td>
#       <td>Weak</td>
#       <td>Yes</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>Rain</td>
#       <td>Mild</td>
#       <td>Normal</td>
#       <td>Weak</td>
#       <td>Yes</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>Sunny</td>
#       <td>Mild</td>
#       <td>Normal</td>
#       <td>Strong</td>
#       <td>Yes</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>Overcast</td>
#       <td>Mild</td>
#       <td>High</td>
#       <td>Strong</td>
#       <td>Yes</td>
#     </tr>
#      <tr>
#       <td>13</td>
#       <td>Overcast</td>
#       <td>Hot</td>
#       <td>Normal</td>
#       <td>Weak</td>
#       <td>Yes</td>
#     </tr>
#        <tr>
#       <td>14</td>
#       <td>Rain</td>
#       <td>Mild</td>
#       <td>High</td>
#       <td>Strong</td>
#       <td>No</td>
#     </tr>
#        </tbody> </table>

# %% [markdown]
# Here,dataset is of binary classes(yes and no), where 9 out of 14 are "yes" and 5 out of 14 are "no".
#
#
# Complete entropy of dataset is:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# For each attribute of the dataset, let's follow the step-2 of pseudocode : -

# %% [markdown]
# ### First Attribute - Outlook
#
# ![image.png](attachment:image.png)

# %% [markdown]
# The __Average Entropy Information for Outlook__ is a measure of the expected reduction in entropy that we can achieve by splitting the data set on the attribute "Outlook".

# %% [markdown]
# ### Second Attribute - Temperature
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Third Attribute - Humidity
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Fourth Attribute - Wind
#
# ![image.png](attachment:image.png)

# %% [markdown]
# __Here, the attribute with maximum information gain is Outlook. So, the decision tree built so far -__

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Here, when Outlook == overcast, it is of pure class(Yes).
#
# Now, we have to repeat same procedure for the data with rows consist of Outlook value as Sunny and then for Outlook value as Rain.
#
# Now, finding the best attribute for splitting the data with Outlook=Sunny values{ Dataset rows = [1, 2, 8, 9, 11]}.

# %% [markdown]
# <table>
#   <thead>
#     <tr>
#       <th>Day</th>
#       <th>Outlook</th>
#       <th>Temperature</th>
#       <th>Humidity</th>
#       <th>Windy</th>
#       <th>PlayTennis</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>Sunny</td>
#       <td>Hot</td>
#       <td>High</td>
#       <td>Weak</td>
#       <td>No</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>Sunny</td>
#       <td>Hot</td>
#       <td>High</td>
#       <td>Strong</td>
#       <td>No</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>Sunny</td>
#       <td>Mild</td>
#       <td>High</td>
#       <td>Weak</td>
#       <td>No</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>Sunny</td>
#       <td>Cool</td>
#       <td>Normal</td>
#       <td>Weak</td>
#       <td>Yes</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>Sunny</td>
#       <td>Mild</td>
#       <td>Normal</td>
#       <td>Strong</td>
#       <td>Yes</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### First Attribute - Temperature
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Second Attribute - Humidity
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Third Attribute - Wind
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Here, the attribute with maximum information gain is Humidity. So, the decision tree built so far -

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Here, when __Outlook = Sunny__ and __Humidity = High__, it is a pure class of category "no". And When __Outlook = Sunny__ and __Humidity = Normal__, it is again a pure class of category "yes". Therefore, we don't need to do further calculations.

# %% [markdown]
# Now, finding the best attribute for splitting the data with Outlook=Rain values{ Dataset rows = [4, 5, 6, 10, 14]}.

# %% [markdown]
# <table>
#   <thead>
#     <tr>
#       <th>Day</th>
#       <th>Outlook</th>
#       <th>Temperature</th>
#       <th>Humidity</th>
#       <th>Windy</th>
#       <th>PlayTennis</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>4</td>
#       <td>Rain</td>
#       <td>Mild</td>
#       <td>High</td>
#       <td>False</td>
#       <td>Yes</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>Rain</td>
#       <td>Cool</td>
#       <td>Normal</td>
#       <td>False</td>
#       <td>Yes</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>Rain</td>
#       <td>Cool</td>
#       <td>Normal</td>
#       <td>True</td>
#       <td>No</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>Rain</td>
#       <td>Mild</td>
#       <td>Normal</td>
#       <td>False</td>
#       <td>Yes</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>Rain</td>
#       <td>Mild</td>
#       <td>High</td>
#       <td>True</td>
#       <td>No</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### First Attribute - Temperature
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Second Attribute - Wind

# %% [markdown]
# Here, the attribute with maximum information gain is Wind. So, the decision tree built so far -
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
#
# Here, when Outlook = Rain and Wind = Strong, it is a pure class of category "no".
#
# q1And When Outlook = Rain and Wind = Weak, it is again a pure class of category "yes".
#
# And this is our final desired tree for the given dataset.

# %% [markdown]
# __Note:__ If we are left with zero features (i.e., all the features have been used for splitting the data) and a leaf node still has impurity, then we can assign the majority class in that leaf node as the predicted class. This is called the "majority voting" or "majority polling" rule, and it is a common strategy for handling impurity in decision trees. By using the majority class, we are essentially taking the "best guess" based on the available information, even if the information is not perfectly pure.

# %% [markdown]
# ### Case Study: Play Tennis

# %%
import pandas as pd
import numpy as np


# Visualization imports
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline


from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### Read data from file
# pd.read_csv() is a function from the Pandas library that is used to read data from a CSV (Comma-Separated Values) file and create a Pandas DataFrame.
#
#
# In Pandas, a DataFrame is a two-dimensional labeled data structure, similar to a table in a spreadsheet or a SQL database. It consists of rows and columns, where each column can have a different data type (e.g., numeric, string, boolean, datetime, etc.).

# %%
data = pd.read_csv("play_tennis.csv")

# %%
data
# Out:
#     day   outlook  temp humidity    wind play
# 0    D1     Sunny   Hot     High    Weak   No
# 1    D2     Sunny   Hot     High  Strong   No
# 2    D3  Overcast   Hot     High    Weak  Yes
# 3    D4      Rain  Mild     High    Weak  Yes
# 4    D5      Rain  Cool   Normal    Weak  Yes
# 5    D6      Rain  Cool   Normal  Strong   No
# 6    D7  Overcast  Cool   Normal  Strong  Yes
# 7    D8     Sunny  Mild     High    Weak   No
# 8    D9     Sunny  Cool   Normal    Weak  Yes
# 9   D10      Rain  Mild   Normal    Weak  Yes
# 10  D11     Sunny  Mild   Normal  Strong  Yes
# 11  D12  Overcast  Mild     High  Strong  Yes
# 12  D13  Overcast   Hot   Normal    Weak  Yes
# 13  D14      Rain  Mild     High  Strong   No

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# __data.shape__ is an attribute of a DataFrame that returns a tuple representing the dimensions of the DataFrame.
#
# The tuple has two elements: the number of rows and the number of columns, respectively.

# %%
data.shape
# Out:
# (14, 6)

# %% [markdown]
# __data.columns__ is an attribute of a DataFrame that returns a list of column labels (i.e., the column names) of the DataFrame.

# %%
data.columns
# Out:
# Index(['day', 'outlook', 'temp', 'humidity', 'wind', 'play'], dtype='object')

# %% [markdown]
# __data.describe()__ Method of a DataFrame that generates descriptive statistics of the numerical columns in the DataFrame. It computes various statistical measures such as count, mean, standard deviation, minimum, maximum, and quartiles of the data in the columns.

# %%
data.describe()
# Out:
#        day outlook  temp humidity  wind play
# count   14      14    14       14    14   14
# unique  14       3     3        2     2    2
# top     D7   Sunny  Mild     High  Weak  Yes
# freq     1       5     6        7     8    9

# %% [markdown]
#  The following code iterates over each column in a Pandas DataFrame and prints the number of null values in each column.

# %%
for column in data.columns:
    print(f"Number of null values in {column}: {data[column].isnull().sum()}")
# Out:
# Number of null values in day: 0
# Number of null values in outlook: 0
# Number of null values in temp: 0
# Number of null values in humidity: 0
# Number of null values in wind: 0
# Number of null values in play: 0

# %% [markdown]
# ## Data Visulaization
# The following code generates a bar chart for each categorical column in a Pandas DataFrame. The code iterates over each column in data.columns except for the column 'day', which is assumed to be a non-categorical column.
#
#
# Here's what the code does:
#
# * The for loop iterates over each element in the list returned by data.columns, which is a list of column names.
#
# * For each column name, the code checks if the column is not equal to 'day'. If the column is not 'day', it is assumed to be a categorical column.
#
# * The code creates a new figure using the plt.subplots() function, which returns a tuple of a Figure instance and an Axes instance.
#
# * The value_counts() method is called on the column to get a Pandas Series of the unique values in the column and their frequencies.
#
# * The bar() method creates a bar chart of the value frequencies using the unique values of the column as the x-axis and their corresponding frequencies as the height of the bars on the y-axis.
#
# * The set_xlabel() method and the set_ylabel() method are called on the Axes instance to set the x-axis and y-axis labels, respectively.
#
# * The show() method is called on the plt module to display the plot.

# %%
for column in data.columns:
    if column != 'day':
        fig, ax = plt.subplots()
        ax.bar(data[column].value_counts().index, data[column].value_counts().values)
        ax.set_xlabel(column)
        ax.set_ylabel('Frequency')
        plt.show()

# %%
data["play"].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %% [markdown]
# ## Label  Encoding

# %% [markdown]
# LabelEncoder() is a class in the sklearn.preprocessing module of the Scikit-learn library in Python that can be used to convert categorical data into numerical data.
#
# After the fit_transform() method is applied to each of the categorical features in the dataset, the original categorical data is replaced with the corresponding numerical values. This is useful because many machine learning algorithms require that the data be in numerical format.
#
# In this case, since the 'outlook', 'temp', 'humidity', 'wind', and 'play' features are categorical, we use the LabelEncoder() to transform them to numerical values so that they can be used as input features for a machine learning model.

# %%
# Le = LabelEncoder()
# data['outlook'] = Le.fit_transform(data['outlook'])
# data['temp'] = Le.fit_transform(data['temp'])
# data['humidity'] = Le.fit_transform(data['humidity'])
# data['wind'] = Le.fit_transform(data['wind'])
# data['play'] = Le.fit_transform(data['play'])

# %% [markdown]
# ### Alternate Method:
# A mapping from categorical variables to numerical variables without using the LabelEncoder() class from Scikit-learn:

# %%
# Define a dictionary to map the categorical variables to numerical variables
outlook_map = {'Sunny': 0, 'Overcast': 1, 'Rain': 2}
temp_map = {'Hot': 0, 'Mild': 1, 'Cool': 2}
humidity_map = {'High': 0, 'Normal': 1}
wind_map = {'Weak': 0, 'Strong': 1}
play_map = {'No': 0, 'Yes': 1}

# Use the mapping dictionaries to replace the categorical variables with numerical variables
data['outlook'] = data['outlook'].replace(outlook_map)
data['temp'] = data['temp'].replace(temp_map)
data['humidity'] = data['humidity'].replace(humidity_map)
data['wind'] = data['wind'].replace(wind_map)
data['play'] = data['play'].replace(play_map)

# %%
data
# Out:
#     day  outlook  temp  humidity  wind  play
# 0    D1        0     0         0     0     0
# 1    D2        0     0         0     1     0
# 2    D3        1     0         0     0     1
# 3    D4        2     1         0     0     1
# 4    D5        2     2         1     0     1
# 5    D6        2     2         1     1     0
# 6    D7        1     2         1     1     1
# 7    D8        0     1         0     0     0
# 8    D9        0     2         1     0     1
# 9   D10        2     1         1     0     1
# 10  D11        0     1         1     1     1
# 11  D12        1     1         0     1     1
# 12  D13        1     0         1     0     1
# 13  D14        2     1         0     1     0

# %%
print("outlook: ", data["outlook"].unique())
print("temp:" ,data["temp"].unique())
print("humidity: ", data["humidity"].unique())
print("wind:", data["wind"].unique())
# Out:
# outlook:  [0 1 2]
# temp: [0 1 2]
# humidity:  [0 1]
# wind: [0 1]

# %% [markdown]
# ### Splitting the Data into Training and Testing Sets

# %% [markdown]
# This code is splitting the dataset into training and test sets using the train_test_split function from scikit-learn.
#
# The test_size parameter is set to 0.2, which means that 20% of the data will be used for testing and 80% for training
#
# The random_state parameter is set to 0 to ensure that the results are reproducible.

# %%
X = data[['outlook', 'temp', 'humidity', 'wind']]
y = data['play']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
print(type(X_train), X_train.shape )
print(type(X_test), X_test.shape )

print(type(y_train), y_train.shape )
print(type(y_test), y_test.shape )
# Out:
# <class 'pandas.core.frame.DataFrame'> (11, 4)
# <class 'pandas.core.frame.DataFrame'> (3, 4)
# <class 'pandas.core.series.Series'> (11,)
# <class 'pandas.core.series.Series'> (3,)

# %% [markdown]
# ### Decision Tree Classifier

# %% [markdown]
# __DTC_Model = DecisionTreeClassifier(criterion= 'entropy', max_depth=4, random_state=10)__ creates an instance of the DecisionTreeClassifier class from scikit-learn with the following parameters:
#
# __criterion='entropy':__  the function to measure the quality of a split. In this case, the criterion is set to 'entropy' which means that the decision tree algorithm will use the entropy measure to evaluate the quality of each split.
#
# __max_depth=4:__ the maximum depth of the decision tree. The tree will stop growing when the maximum depth is reached.
# random_state=10: the seed value for the random number generator. This is used to ensure that the same results are obtained each time the code is run.
#
# __DTC_Model.fit(X_train, y_train)__ fits the decision tree model to the training data. X_train contains the features (i.e., the input variables) and y_train contains the target variable (i.e., the output variable) for the training data. The fit method trains the model by using the decision tree algorithm to build a tree that can make predictions based on the input features. Once the model is trained, it can be used to predict the target variable for new data.

# %%
DTC_Model =DecisionTreeClassifier(criterion= 'entropy', max_depth=4, random_state=10)

DTC_Model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4, random_state=10)

# %% [markdown]
# score() is a method to calculate the accuracy of the model on the training data. The method returns the mean accuracy on the given data and labels.

# %%
DTC_Model.score(X_train , y_train)
# Out:
# 1.0

# %% [markdown]
# y_pred contains the predicted values of the target variable (i.e., whether to play tennis or not) for the test set. The model was trained on the training set and then used to predict the target variable for the test set using the predict() method. These predictions are stored in y_pred.

# %%
y_pred = DTC_Model.predict(X_test)

# %%
print(y_pred)

# now print the actual labels
print(y_test)
# Out:
# [1 1 1]
# 8    1
# 6    1
# 4    1
# Name: play, dtype: int64

# %% [markdown]
# The score() method of a decision tree classifier in scikit-learn is used to calculate the mean accuracy on the given test data and labels. It returns the accuracy of the classifier on the given test set.

# %%
DTC_Model.score(X_test , y_test)
# Out:
# 1.0

# %%
# DTC_tree = tree.plot_tree(DTC_Model)
plt.figure(figsize=(10, 9))

DTC_tree = tree.plot_tree(DTC_Model, filled=True, 
                          feature_names=['outlook', 'temp', 'humidity', 'wind'],
                          fontsize=10,  
                          )

# %% [markdown]
# ### Characteristics of ID3
#
# Characteristics of ID3 Algorithm are as follows:
#
# * ID3 uses a greedy approach that's why it does not guarantee an optimal solution; it can get stuck in local optimums.
#
# * ID3 can overfit to the training data (to avoid overfitting, smaller decision trees should be preferred over larger ones).
#
# * This algorithm usually produces small trees, but it does not always produce the smallest possible tree.
#
# * ID3 is harder to use on continuous data (if the values of any given attribute is continuous, then there are many more places to split the data on this attribute, and searching for the best value to split by can be time consuming).

# %% [markdown]
# ## Task
#
#
# 1. Load the iris dataset using scikit-learn.
#
# 2. Split the dataset into training and testing sets with 70% of the data for training and 30% for testing.
#
# 3. Train a decision tree classifier using the entropy criterion and evaluate its accuracy on the testing set.
#
# 4. Train another decision tree classifier using the gini criterion and evaluate its accuracy on the testing set.
#
# 5. Compare the performance of the two classifiers and discuss the differences in terms of accuracy.
#
# 6. Visualize the decision tree for each classifier and compare the tree structure and feature importance.
#
#
# __Note:__ You can use the tree.plot_tree() function to visualize the decision tree, and the feature_importances_ attribute to get the feature importances for each classifier.
#
# The __feature importance values__ can be used to understand which features have the strongest association with the target variable and how they contribute to the model's prediction.

# %%
#imports
from sklearn.datasets import load_iris
from sklearn import tree
import pandas as pd

# %%
data = load_iris()

# %%
type(data)
# Out:
# sklearn.utils.Bunch

# %%
data = load_iris()
df = pd.DataFrame(data=data.data, columns=data.feature_names)

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
from sklearn import metrics
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plot
from sklearn.tree import DecisionTreeClassifier,plot_tree
import matplotlib.pyplot as plot

# %%
x = data.data
y = data.target

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
data.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
cl_ent = DecisionTreeClassifier(criterion='entropy')
cl_ent.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
cl1_gini = DecisionTreeClassifier(criterion='gini')
cl1_gini.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
print("Train Data Accuracy:", cl_ent.score(x_test, y_test))
print("Test Data Accuracy:", cl1_gini.score(x_test, y_test))
# Out:
# Train Data Accuracy: 0.9777777777777777
# Test Data Accuracy: 0.9777777777777777

# %%
print("Entropy Feature Importances:", cl_ent.feature_importances_)
print("Gini Feature Importances:", cl1_gini.feature_importances_)
# Out:
# Entropy Feature Importances: [0.01202963 0.         0.32797309 0.65999727]
# Gini Feature Importances: [0.01430128 0.         0.40296358 0.58273514]
